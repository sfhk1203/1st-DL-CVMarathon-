# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
w=3
b=0.5
x_lin = np.linspace(0, 100, 101)
y = (x_lin + np.random.randn(101) * 5) * w + b
plt.plot(x_lin, y, 'b.', label = 'data points')
plt.title("Assume we have data points")
plt.legend(loc = 2)
plt.show()

# %%
y_hat = x_lin * w + b
plt.plot(x_lin, y, 'b.', label = 'data')
plt.plot(x_lin, y_hat, 'r-', label = 'prediction')
plt.title("Assume we have data points (And the prediction)")
plt.legend(loc = 2)
plt.show()

# %%
def mean_absolute_error(y,yp):
    mae=MAE=sum(abs(y-yp)/len(y))
    return mae
MAE=mean_absolute_error(y,y_hat)
print("The mean absolute error is %.3f" %(MAE))
# Out:
# The mean absolute error is 12.920

# %%
def mean_squared_error(y,y_hat):
    MSE=sum((y-y_hat)**2)
    return MSE
MSE=mean_squared_error(y,y_hat)
print("the mean squared error is %.3f" %(MSE))
# Out:
# the mean squared error is 25915.591

# %%
https://www.kaggle.com/alexgude/california-traffic-collision-data-from-switrs
1.你選的這組資料為何重要:統計交通事故的事件
2.資料從何而來:Alex Gude所提供，透過California 鐵路巡邏隊的協助所完成
3.蒐集而來的資料型態為何:結構化型態
4.這組資料想解決的問題如何評估:發生事故的人→考慮性別、年齡、有沒有酒駕→回歸：MSE
# Out:
#   File "<ipython-input-9-216bd26f1f6f>", line 1
#     https://www.kaggle.com/alexgude/california-traffic-collision-data-from-switrs
#           ^
# SyntaxError: invalid syntax

# %%
1. 核心問題為何 :提升業績 就是增加計程車載客率、降低乘客等車時間，利用數據分析出哪時段的載客量偏高，加開班次；或是利用數據分析指出哪地方載客量較高，多派班次往該地點駐守
2. 資料從何而來 :透過以往乘客乘車的地點與乘車時間之歷史來判斷
3. 蒐集而來的資料型態為何　:結構化資料
4. 你要回答的問題，其如何評估 :透過計算上傳值與實際值的方均根差RMSE來評估
# Out:
#   File "<ipython-input-6-0df939446bcd>", line 1
#     pip3 install web.py
#          ^
# SyntaxError: invalid syntax
